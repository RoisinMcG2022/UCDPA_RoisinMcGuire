# %%
#import pandas, numpy, pyplot and seaborn
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

#read dataset from csv file
df=pd.read_csv(r'C:/Python/datasets/Video_Games_Dataset.csv')
pd.set_option('display.max_rows', 100)

#view top 20 rows
df.head(20)
# Out:
#     Rank                                          Name Platform  Year  \
# 0      1                                    Wii Sports      Wii  2006
# 1      2                             Super Mario Bros.      NES  1985
# 2      3                                Mario Kart Wii      Wii  2008
# 3      4                             Wii Sports Resort      Wii  2009
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996
# 5      6                                        Tetris       GB  1989
# 6      7                         New Super Mario Bros.       DS  2006
# 7      8                                      Wii Play      Wii  2006
# 8      9                     New Super Mario Bros. Wii      Wii  2009
# 9     10                                     Duck Hunt      NES  1984
# 10    11                                    Nintendogs       DS  2005
# 11    12                                 Mario Kart DS       DS  2005
# 12    13                   Pokemon Gold/Pokemon Silver       GB  1999
# 13    14                                       Wii Fit      Wii  2007
# 14    15                                  Wii Fit Plus      Wii  2009
# 15    16                            Kinect Adventures!     X360  2010
# 16    17                            Grand Theft Auto V      PS3  2013
# 17    19                             Super Mario World     SNES  1990
# 18    20  Brain Age: Train Your Brain in Minutes a Day       DS  2005
# 19    21                 Pokemon Diamond/Pokemon Pearl       DS  2006
#
#            Genre               Publisher  NorthAmerica_Sales  \
# 0         Sports                Nintendo               41.49
# 1       Platform                Nintendo               29.08
# 2         Racing                Nintendo                 NaN
# 3         Sports                Nintendo               15.75
# 4   Role-Playing                Nintendo               11.27
# 5         Puzzle                Nintendo               23.20
# 6       Platform                Nintendo               11.38
# 7           Misc                Nintendo               14.03
# 8       Platform                Nintendo               14.59
# 9        Shooter                Nintendo               26.93
# 10    Simulation                Nintendo                9.07
# 11        Racing                Nintendo                9.81
# 12  Role-Playing                Nintendo                 NaN
# 13        Sports                Nintendo                8.94
# 14        Sports                Nintendo                9.09
# 15          Misc  Microsoft Game Studios               14.97
# 16        Action    Take-Two Interactive                7.01
# 17      Platform                Nintendo               12.78
# 18          Misc                Nintendo                4.75
# 19  Role-Playing                Nintendo                6.42
#
#     EurpeanUnion_Sales  Japan_Sales  Other_Sales  Global_Sales
# 0                29.02         3.77         8.46         82.74
# 1                 3.58         6.81         0.77         40.24
# 2                12.88         3.79          NaN         35.82
# 3                11.01          NaN         2.96         33.00
# 4                 8.89        10.22         1.00         31.37
# 5                 2.26         4.22         0.58           NaN
# 6                 9.23         6.50         2.90         30.01
# 7                 9.20         2.93         2.85         29.02
# 8                 7.06          NaN         2.26         28.62
# 9                  NaN         0.28         0.47         28.31
# 10               11.00         1.93         2.75         24.76
# 11                7.57         4.13         1.92         23.42
# 12                6.18         7.20         0.71         23.10
# 13                8.03         3.60         2.15           NaN
# 14                8.59         2.53         1.79         22.00
# 15                4.94         0.24         1.67           NaN
# 16                9.27         0.97         4.14         21.40
# 17                 NaN         3.54         0.55         20.61
# 18                9.26          NaN         2.05         20.22
# 19                4.52         6.04         1.37         18.36

# %%
#get max, min and mean global sales
df['Global_Sales'].max()
#df['Global_Sales'].min()
#df['Global_Sales'].mean()
# Out:
# 82.74

# %%
Genre_by_Year = df.groupby(["Genre", "Platform", "Year"])["Genre"].count()
pd.set_option('display.max_rows',200)
print(Genre_by_Year)
# Out:
# Genre         Platform  Year
# Action        DS        2007    1
#                         2009    1
#               N64       1998    1
#               NES       1986    1
#               PS        1996    1
#                         1997    1
#                         1998    2
#                         1999    1
#                         2000    1
#               PS3       2007    1
#                         2008    2
#                         2009    3
#                         2010    2
#                         2011    2
#                         2012    2
#                         2013    2
#               PS4       2014    1
#               PSP       2005    1
#                         2006    1
#               Wii       2006    1
#                         2007    1
#               X360      2008    1
#                         2009    1
#                         2010    1
#                         2011    1
#                         2012    2
#                         2013    1
#               XOne      2014    1
# Adventure     GB        1992    1
#               PS3       2007    1
#               X360      2007    1
# Fighting      3DS       2014    1
#               GC        2001    1
#               N64       1999    1
#               PS        1996    1
#                         1998    1
#               SNES      1992    1
#               Wii       2008    1
#               WiiU      2014    1
# Misc          DS        2005    2
#                         2007    1
#               GB        1999    1
#               PS3       2014    1
#               Wii       2006    1
#                         2007    1
#                         2009    1
#                         2010    2
#                         2011    1
#               X360      2010    1
#                         2013    1
# Platform      3DS       2011    1
#                         2012    1
#               DS        2004    1
#                         2006    1
#               GB        1989    1
#                         1992    1
#                         1999    1
#               GBA       2001    2
#                         2003    1
#               GC        2002    1
#               GEN       1992    1
#               N64       1996    1
#                         1999    1
#               NES       1985    1
#                         1988    2
#               PS        1996    1
#                         1997    1
#                         1998    2
#               PS3       2008    1
#               SNES      1990    1
#                         1993    1
#                         1994    1
#                         1995    1
#               Wii       2007    1
#                         2009    1
#                         2010    2
# Puzzle        2600      1982    1
#               DS        2005    1
#                         2007    1
#               GB        1989    2
#               NES       1988    1
#                         1990    1
# Racing        3DS       2011    1
#               DS        2005    1
#               GBA       2001    1
#               GC        2003    1
#               N64       1996    1
#                         1997    1
#               PS        1997    1
#                         1999    2
#               PS3       2010    1
#               SNES      1992    1
#               Wii       2008    1
#               WiiU      2014    1
#               X360      2009    1
# Role-Playing  3DS       2013    1
#                         2014    1
#               DS        2006    1
#                         2007    1
#                         2008    1
#                         2009    1
#                         2010    1
#                         2012    1
#               GB        1996    1
#                         1998    1
#                         1999    1
#                         2000    1
#               GBA       2002    1
#                         2004    2
#               PC        2004    1
#                         2012    1
#               PS        1997    1
#                         1999    1
#                         2000    1
#               PS3       2009    1
#                         2011    1
#               PS4       2015    1
#               PSP       2008    1
#                         2010    1
#               X360      2008    1
#                         2010    1
#                         2011    1
# Shooter       N64       1997    1
#               NES       1984    1
#               PS3       2007    1
#                         2008    1
#                         2009    1
#                         2010    1
#                         2011    2
#                         2012    1
#                         2013    1
#               PS4       2014    2
#                         2015    2
#               Wii       2007    1
#               X360      2006    1
#                         2007    2
#                         2008    2
#                         2009    2
#                         2010    2
#                         2011    3
#                         2012    2
#                         2013    1
#               XB        2001    1
#                         2004    1
#               XOne      2014    1
#                         2015    1
# Simulation    3DS       2012    1
#                         2013    1
#               DS        2005    2
#                         2006    1
#               PC        1996    1
#                         2009    1
# Sports        DS        2008    1
#               PS        1999    1
#               PS3       2010    1
#                         2011    1
#                         2014    1
#               PS4       2014    1
#                         2015    1
#                         2016    1
#               Wii       2006    1
#                         2007    2
#                         2009    2
#                         2010    1
#               X360      2010    1
# Strategy      N64       1999    1
#               PC        2010    1
#               PS        1999    1
# Name: Genre, dtype: int64

# %%
#Which genre sold the most in a year, Action sold 3
Genre_by_Year.max()
# Out:
# 3

# %%
#large variety of genres across decades so there is a lot of null values 
df.pivot_table(index='Year', columns='Genre', values='Global_Sales', aggfunc=['max']).dropna(thresh=6)
# Out:
#          max                                                                \
# Genre Action Adventure Fighting   Misc Platform Puzzle Racing Role-Playing
# Year
# 1996    5.05       NaN     5.74    NaN    11.89    NaN   9.87        31.37
# 1999    6.27       NaN      NaN   5.31     5.27    NaN   4.79        23.10
# 2006    7.31       NaN      NaN  29.02    30.01    NaN    NaN        18.36
# 2007    5.83      5.55      NaN   9.02    11.52   5.26    NaN         4.96
# 2008   11.02       NaN    13.04    NaN     5.92    NaN  35.82         7.84
# 2009   11.90       NaN      NaN   7.27    28.62    NaN    NaN         5.84
# 2010    6.60       NaN      NaN   9.52     7.69    NaN  10.77        15.32
# 2011    6.83       NaN      NaN  10.26    10.79    NaN  12.21         8.84
# 2014   11.98       NaN     7.45   5.42      NaN    NaN   6.96        11.33
#
#
# Genre Shooter Simulation Sports Strategy
# Year
# 1996      NaN       5.12    NaN      NaN
# 1999      NaN        NaN   5.02     5.45
# 2006     6.11       5.72  82.74      NaN
# 2007     9.32        NaN   8.06      NaN
# 2008     7.37        NaN   5.14      NaN
# 2009    13.51       8.11  33.00      NaN
# 2010    14.64        NaN   6.24     4.83
# 2011    14.76        NaN   6.69      NaN
# 2014     7.60        NaN   6.59      NaN

# %%
#1996 and 1999 showing a peak in role-playing games (Pokemon on Gameboy), Mario Kart 2008 Racing, 
#New Super Mario Bros. on Wii 2009 is Platform, Wii Fit Plus is Sports.

#create bar chart from pivot table
df.pivot_table(index='Year', columns='Genre', values='Global_Sales', aggfunc=['max']).dropna(thresh=6).plot(kind='bar', figsize=(15,8))

plt.show()

# %%
#Average globl sales for Action
df.loc[df['Genre'] == 'Action', 'Global_Sales'].mean()
# Out:
# 7.262499999999999

# %%
#Average Global Sales for Sports
df.loc[df['Genre'] == 'Sports', 'Global_Sales'].mean()
# Out:
# 15.280000000000003

# %%
#Average global sales for Platformers
df.loc[df['Genre'] == 'Platform', 'Global_Sales'].mean()
# Out:
# 11.203793103448275

# %%
#Average global sales for Role-Playing
df.loc[df['Genre'] == 'Role-Playing', 'Global_Sales'].mean()
# Out:
# 9.897142857142855

# %%
#Average Global sales for Racing
df.loc[df['Genre'] == 'Racing', 'Global_Sales'].mean()
# Out:
# 11.737499999999999

# %%
#Create bar graph showing genre sales by copies using groupby()

ax=df.groupby('Genre')['Global_Sales'].max().plot(kind='bar', figsize=(15,8),color=['pink', 'red', 'maroon', 'purple', 'blue', 'cyan'])

#set x and y labels
ax.set(xlabel='Genre', ylabel='Copies of Game Sold (Millions)')
# Out:
# [Text(0.5, 0, 'Genre'), Text(0, 0.5, 'Copies of Game Sold (Millions)')]

# %%
#Show max global sales for Genres by year
df.groupby(['Year','Genre'])['Global_Sales'].max()
# Out:
# Year  Genre
# 1982  Puzzle           7.81
# 1984  Shooter         28.31
# 1985  Platform        40.24
# 1986  Action           6.51
# 1988  Platform        17.28
#                       ...
# 2014  Sports           6.59
# 2015  Role-Playing     6.96
#       Shooter         14.24
#       Sports           8.49
# 2016  Sports           4.77
# Name: Global_Sales, Length: 124, dtype: float64

# %%
#Min and Max sales by genre
df.groupby('Genre')['Global_Sales'].agg(['min','max'])
# Out:
#                min    max
# Genre
# Action        4.76  21.40
# Adventure     4.83  11.18
# Fighting      5.02  13.04
# Misc          5.31  29.02
# Platform      5.00  40.24
# Puzzle        5.26  15.30
# Racing        4.79  35.82
# Role-Playing  4.87  31.37
# Shooter       5.00  28.31
# Simulation    5.12  24.76
# Sports        4.77  82.74
# Strategy      4.83   5.45

# %%
#Min and Max sales by genre plot
ax=df.groupby('Genre')['Global_Sales'].agg(['min','max']).plot(kind='bar', figsize=(15,8),color=['pink','purple'])
ax.set(xlabel='Genre', ylabel='Copies of Game Sold (Millions)')
plt.show()

# %%
#Yearly sales
ax=df.groupby(['Year'])['Global_Sales'].max().plot(kind='bar', figsize=(15,8), color=['brown','red', 'orange', 'yellow'])
ax.set(xlabel='Year', ylabel='Copies of Game Sold (Millions)')
plt.show()
