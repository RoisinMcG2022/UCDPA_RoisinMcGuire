# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df=pd.read_csv(r'C:/Python/datasets/year_genre_region.csv')

df.head()

#genre_focus = ['Action']
#for genre in YGR:
   # if genre in genre_focus:
    
genre_focus = ['Action']


#print(YGR.genre[::3

#df[(df["release_year"] <= 2020) | (df["genre"] == "Action")]


plt.plot(df["release_year"], df["genre"])


plt.xlabel('Release Year')
# naming the y axis
plt.ylabel('Action Sales')

# giving a title to my graph
plt.title('Action Sales by Year')



#plt.show()
# Out:
# Text(0.5, 1.0, 'Action Sales by Year')

# %%
col_range = list(range(2))
col_range
# Out:
# [0, 1]

# %%
YG = YGR.iloc[:, col_range]
YG
# Out:
#       release_year         genre
# 0             1980        Action
# 1             1980      Fighting
# 2             1980          Misc
# 3             1980       Shooter
# 4             1980        Sports
# ...            ...           ...
# 1945          2016        Sports
# 1946          2016      Strategy
# 1947          2017        Action
# 1948          2017  Role-Playing
# 1949          2020    Simulation
#
# [1950 rows x 2 columns]

# %%
YGR['genre'].value_counts()
# Out:
# Action          190
# Sports          185
# Shooter         180
# Platform        180
# Puzzle          170
# Racing          160
# Role-Playing    160
# Misc            155
# Simulation      155
# Fighting        145
# Adventure       140
# Strategy        130
# Name: genre, dtype: int64

# %%
plt.plot(YGR.release_year, YGR.genre)
plt.show()
