# %%
#Import pandas, numpy, pyplot from matplotlib and seaborn
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

#Read CSV file Year_Genre_Region
df=pd.read_csv(r'C:/Python/datasets/year_genre_region.csv', delimiter=',')

#Print first five rows
df.head()
# Out:
#    release_year     genre         region  sales
# 0          1980    Action  North America   0.32
# 1          1980  Fighting  North America   0.72
# 2          1980      Misc  North America   2.53
# 3          1980   Shooter  North America   6.56
# 4          1980    Sports  North America   0.46

# %%
#Check how many unique variables are in Region
df["region"].unique()
# Out:
# array(['North America', 'European Union', 'Japan', 'Other', 'Worldwide'],
#       dtype=object)

# %%
#Global Game Sales by Region, 1980-2020
ax=sns.relplot(x='release_year', y='sales',
          data=df,
          kind='line',
          hue='region')

#ax.set_xticks(range(len(df)), labels=range(1980, 2016))

ax.set(xlabel='Year', ylabel='Sales in Dollars(billions)')

plt.show()

# %%
#Pivot table showing the average figures for all genres from (1991-2016), remove thresh to see complete data with incomplete years.
df.pivot_table(index='release_year', columns='genre', values='sales', aggfunc=['mean']).dropna(thresh=5)
# Out:
#                 mean                                                      \
# genre         Action Adventure Fighting    Misc Platform  Puzzle  Racing
# release_year
# 1980           0.136       NaN    0.308   1.082      NaN     NaN     NaN
# 1981           5.926       NaN      NaN     NaN    2.770   0.898   0.192
# 1982           2.604       NaN      NaN   0.348    2.012   4.014   0.628
# 1983           1.144     0.160      NaN   0.856    2.772   0.312     NaN
# 1984           0.740       NaN      NaN   0.580    0.276   1.256   2.380
# 1985           1.408       NaN    0.420     NaN   17.268   1.284     NaN
# 1986           5.496       NaN      NaN     NaN    3.756     NaN   0.784
# 1987           0.446     1.752    2.168     NaN    0.696     NaN     NaN
# 1988           0.698       NaN      NaN     NaN   11.092   2.232   0.856
# 1989           1.858       NaN      NaN   0.512    8.264  15.100     NaN
# 1990           2.556       NaN      NaN     NaN    9.190   2.398   2.502
# 1991           2.704     0.896    0.156   0.032    3.054   1.296   0.456
# 1992           1.534     4.898    6.096   1.976    5.366   1.936   3.618
# 1993           0.724     0.028    3.500   0.120    7.470   1.268   0.144
# 1994           0.620     1.496    3.392   1.144   11.500   0.612   0.874
# 1995           1.430     0.286    5.938   2.560    6.676   1.080   2.436
# 1996           8.236     1.674    7.220   4.268   11.292   1.566  11.302
# 1997          11.034     1.986    4.712   2.274    8.742   2.352  12.766
# 1998          15.770     3.618   12.668   4.768   11.942   2.538  11.156
# 1999          11.100     3.042    5.714   8.266    8.324   0.540  14.892
# 2000          13.604     1.188    8.096   6.218    6.422   1.530   7.998
# 2001          23.754     3.652    7.244   6.558   15.722   3.188  22.328
# 2002          34.682     4.428    9.988   6.260   18.384   2.134  12.070
# 2003          27.182     0.852    9.504   9.522   17.140   0.968  20.874
# 2004          30.476     3.462    6.708  12.496   18.888   3.360  19.140
# 2005          34.184     3.380    7.872  24.410    9.342   8.156  22.412
# 2006          26.438     4.546    8.968  26.808   19.728   4.308  13.534
# 2007          41.964     9.646    6.996  36.596   14.034   9.460  15.530
# 2008          53.994     9.868   14.012  34.422   14.054   6.104  28.014
# 2009          55.070     8.086   12.756  30.322   16.222   7.918  13.468
# 2010          46.156     6.392    5.882  38.068   12.404   4.298  13.746
# 2011          46.688     6.244    8.956  21.766   11.078   1.982  13.928
# 2012          47.670     2.318    3.676   8.886    7.348   0.688   5.458
# 2013          49.016     2.432    2.826  10.110    9.826   0.382   4.940
# 2014          38.906     2.236    6.336   9.346    3.518   0.596   6.660
# 2015          28.812     3.262    3.164   4.626    2.422   0.286   3.228
# 2016          12.068     1.530    1.782   1.046    1.288   0.004   1.124
#
#
# genre        Role-Playing Shooter Simulation  Sports Strategy
# release_year
# 1980                  NaN   2.828        NaN   0.198      NaN
# 1981                  NaN   4.012      0.178   0.314      NaN
# 1982                  NaN   1.520        NaN   0.422      NaN
# 1983                  NaN   0.194        NaN   1.280      NaN
# 1984                  NaN  12.440        NaN   2.470      NaN
# 1985                  NaN   0.400      0.014   0.784      NaN
# 1986                1.008   1.556        NaN   2.230      NaN
# 1987                1.860   0.280        NaN   1.486      NaN
# 1988                2.352   0.204      0.012   1.440      NaN
# 1989                0.880   0.478        NaN   2.288      NaN
# 1990                1.808     NaN      0.454   0.844      NaN
# 1991                1.302   0.798      0.858   0.964    0.376
# 1992                2.744   0.114      0.856   1.180    0.148
# 1993                2.236   1.232      0.076   1.272    0.324
# 1994                2.848   3.320      1.090   3.360    1.426
# 1995                5.706   1.660      1.670   3.194    2.610
# 1996               17.590   2.762      4.532   6.974    2.244
# 1997                8.722   8.866      3.858  12.012    3.086
# 1998               11.232   3.920      2.844  16.708    5.388
# 1999               19.636   4.896      4.580  12.100    7.382
# 2000               11.616   2.728      1.350  16.486    3.412
# 2001                8.816   9.916      7.816  20.578    3.014
# 2002               18.052  19.410      4.326  26.146    2.216
# 2003               12.108  10.844      8.476  22.414    3.184
# 2004               21.582  18.778      4.340  25.456    2.860
# 2005               11.360  16.614     19.578  23.800    2.118
# 2006               22.948  15.296      8.616  54.322    1.674
# 2007               17.382  28.256     19.354  39.102    3.704
# 2008               23.602  23.676     18.440  37.842    4.630
# 2009               18.920  27.718     13.190  54.940    4.930
# 2010               27.844  30.740      8.608  36.516    5.490
# 2011               21.136  39.270      6.054  22.440    3.532
# 2012               18.764  28.710      5.344  12.168    1.306
# 2013               17.774  24.818      3.450  16.480    2.442
# 2014               18.238  26.094      2.234  18.050    0.394
# 2015               15.060  27.000      2.260  16.348    0.738
# 2016                7.260  15.290      0.756   9.404    0.456

# %%
#Create pivot table showing region sales since the 1980's
df.pivot_table(index='release_year', columns='region', values='sales', aggfunc=['max']).dropna(thresh=5).plot(kind='bar', figsize=(15,8))
plt.show()

# %%
#Set decade bucket to get a clearer view of region sales since the 1980's
df['decade'] = [release_year//10*10 for release_year in df.release_year]

df.head()
# Out:
#    release_year     genre         region  sales  decade
# 0          1980    Action  North America   0.32    1980
# 1          1980  Fighting  North America   0.72    1980
# 2          1980      Misc  North America   2.53    1980
# 3          1980   Shooter  North America   6.56    1980
# 4          1980    Sports  North America   0.46    1980

# %%
#Display region buckets

df.pivot_table(index='decade', columns='region', values='sales', aggfunc=['max']).dropna(thresh=5).plot(kind='bar', figsize=(15,8))

plt.xticks(rotation=45)
plt.xlabel('Decade')
plt.ylabel('Sales in Billions')

plt.show()

# %%
#find how many unique variables are in genre
df["genre"].unique()
# Out:
# array(['Action', 'Fighting', 'Misc', 'Shooter', 'Sports', 'Platform',
#        'Puzzle', 'Racing', 'Simulation', 'Adventure', 'Role-Playing',
#        'Strategy'], dtype=object)

# %%
#df[(df.genre== 'Action') & (df.region == 'North America')]

#(df.loc[df['genre'] == 'Action'])

# %%
sns.relplot(x='release_year', 
            y='sales', 
            data =df, palette=['yellow', 'green', 'orange', 'pink', 'red', 'maroon', 'purple', 'blue', 'cyan', 'violet', 'brown', 'black'],
           hue='genre')

# %%
#release year and sales showing genre and grouped my region.
sns.relplot(x='release_year', 
            y='sales', 
            data =df,
           col='region',
           hue='genre')

# %%
df_pivot=pd.pivot_table(df, values='sales', columns='genre', index='release_year').dropna(thresh=12)

df_pivot
# Out:
# genre         Action  Adventure  Fighting    Misc  Platform  Puzzle  Racing  \
# release_year
# 1991           2.704      0.896     0.156   0.032     3.054   1.296   0.456
# 1992           1.534      4.898     6.096   1.976     5.366   1.936   3.618
# 1993           0.724      0.028     3.500   0.120     7.470   1.268   0.144
# 1994           0.620      1.496     3.392   1.144    11.500   0.612   0.874
# 1995           1.430      0.286     5.938   2.560     6.676   1.080   2.436
# 1996           8.236      1.674     7.220   4.268    11.292   1.566  11.302
# 1997          11.034      1.986     4.712   2.274     8.742   2.352  12.766
# 1998          15.770      3.618    12.668   4.768    11.942   2.538  11.156
# 1999          11.100      3.042     5.714   8.266     8.324   0.540  14.892
# 2000          13.604      1.188     8.096   6.218     6.422   1.530   7.998
# 2001          23.754      3.652     7.244   6.558    15.722   3.188  22.328
# 2002          34.682      4.428     9.988   6.260    18.384   2.134  12.070
# 2003          27.182      0.852     9.504   9.522    17.140   0.968  20.874
# 2004          30.476      3.462     6.708  12.496    18.888   3.360  19.140
# 2005          34.184      3.380     7.872  24.410     9.342   8.156  22.412
# 2006          26.438      4.546     8.968  26.808    19.728   4.308  13.534
# 2007          41.964      9.646     6.996  36.596    14.034   9.460  15.530
# 2008          53.994      9.868    14.012  34.422    14.054   6.104  28.014
# 2009          55.070      8.086    12.756  30.322    16.222   7.918  13.468
# 2010          46.156      6.392     5.882  38.068    12.404   4.298  13.746
# 2011          46.688      6.244     8.956  21.766    11.078   1.982  13.928
# 2012          47.670      2.318     3.676   8.886     7.348   0.688   5.458
# 2013          49.016      2.432     2.826  10.110     9.826   0.382   4.940
# 2014          38.906      2.236     6.336   9.346     3.518   0.596   6.660
# 2015          28.812      3.262     3.164   4.626     2.422   0.286   3.228
# 2016          12.068      1.530     1.782   1.046     1.288   0.004   1.124
#
# genre         Role-Playing  Shooter  Simulation  Sports  Strategy
# release_year
# 1991                 1.302    0.798       0.858   0.964     0.376
# 1992                 2.744    0.114       0.856   1.180     0.148
# 1993                 2.236    1.232       0.076   1.272     0.324
# 1994                 2.848    3.320       1.090   3.360     1.426
# 1995                 5.706    1.660       1.670   3.194     2.610
# 1996                17.590    2.762       4.532   6.974     2.244
# 1997                 8.722    8.866       3.858  12.012     3.086
# 1998                11.232    3.920       2.844  16.708     5.388
# 1999                19.636    4.896       4.580  12.100     7.382
# 2000                11.616    2.728       1.350  16.486     3.412
# 2001                 8.816    9.916       7.816  20.578     3.014
# 2002                18.052   19.410       4.326  26.146     2.216
# 2003                12.108   10.844       8.476  22.414     3.184
# 2004                21.582   18.778       4.340  25.456     2.860
# 2005                11.360   16.614      19.578  23.800     2.118
# 2006                22.948   15.296       8.616  54.322     1.674
# 2007                17.382   28.256      19.354  39.102     3.704
# 2008                23.602   23.676      18.440  37.842     4.630
# 2009                18.920   27.718      13.190  54.940     4.930
# 2010                27.844   30.740       8.608  36.516     5.490
# 2011                21.136   39.270       6.054  22.440     3.532
# 2012                18.764   28.710       5.344  12.168     1.306
# 2013                17.774   24.818       3.450  16.480     2.442
# 2014                18.238   26.094       2.234  18.050     0.394
# 2015                15.060   27.000       2.260  16.348     0.738
# 2016                 7.260   15.290       0.756   9.404     0.456

# %%
df2 = df_pivot.reset_index()

df2.to_csv('C:/Python/datasets/year_genre.csv', index =True)

#genre_wide = sns.load_dataset("df2").pivot("release_year", "sales", "genre")

#sns.relplot(data=genre_wide, kind="line")

# %%
df2.dtypes
# Out:
# genre
# release_year      int64
# Action          float64
# Adventure       float64
# Fighting        float64
# Misc            float64
# Platform        float64
# Puzzle          float64
# Racing          float64
# Role-Playing    float64
# Shooter         float64
# Simulation      float64
# Sports          float64
# Strategy        float64
# dtype: object

# %%
df2.set_index('release_year')
df['release_year'] = df.release_year.astype(np.int64)
df2
# Out:
# genre  release_year  Action  Adventure  Fighting    Misc  Platform  Puzzle  \
# 0              1991   2.704      0.896     0.156   0.032     3.054   1.296
# 1              1992   1.534      4.898     6.096   1.976     5.366   1.936
# 2              1993   0.724      0.028     3.500   0.120     7.470   1.268
# 3              1994   0.620      1.496     3.392   1.144    11.500   0.612
# 4              1995   1.430      0.286     5.938   2.560     6.676   1.080
# 5              1996   8.236      1.674     7.220   4.268    11.292   1.566
# 6              1997  11.034      1.986     4.712   2.274     8.742   2.352
# 7              1998  15.770      3.618    12.668   4.768    11.942   2.538
# 8              1999  11.100      3.042     5.714   8.266     8.324   0.540
# 9              2000  13.604      1.188     8.096   6.218     6.422   1.530
# 10             2001  23.754      3.652     7.244   6.558    15.722   3.188
# 11             2002  34.682      4.428     9.988   6.260    18.384   2.134
# 12             2003  27.182      0.852     9.504   9.522    17.140   0.968
# 13             2004  30.476      3.462     6.708  12.496    18.888   3.360
# 14             2005  34.184      3.380     7.872  24.410     9.342   8.156
# 15             2006  26.438      4.546     8.968  26.808    19.728   4.308
# 16             2007  41.964      9.646     6.996  36.596    14.034   9.460
# 17             2008  53.994      9.868    14.012  34.422    14.054   6.104
# 18             2009  55.070      8.086    12.756  30.322    16.222   7.918
# 19             2010  46.156      6.392     5.882  38.068    12.404   4.298
# 20             2011  46.688      6.244     8.956  21.766    11.078   1.982
# 21             2012  47.670      2.318     3.676   8.886     7.348   0.688
# 22             2013  49.016      2.432     2.826  10.110     9.826   0.382
# 23             2014  38.906      2.236     6.336   9.346     3.518   0.596
# 24             2015  28.812      3.262     3.164   4.626     2.422   0.286
# 25             2016  12.068      1.530     1.782   1.046     1.288   0.004
#
# genre  Racing  Role-Playing  Shooter  Simulation  Sports  Strategy  \
# 0       0.456         1.302    0.798       0.858   0.964     0.376
# 1       3.618         2.744    0.114       0.856   1.180     0.148
# 2       0.144         2.236    1.232       0.076   1.272     0.324
# 3       0.874         2.848    3.320       1.090   3.360     1.426
# 4       2.436         5.706    1.660       1.670   3.194     2.610
# 5      11.302        17.590    2.762       4.532   6.974     2.244
# 6      12.766         8.722    8.866       3.858  12.012     3.086
# 7      11.156        11.232    3.920       2.844  16.708     5.388
# 8      14.892        19.636    4.896       4.580  12.100     7.382
# 9       7.998        11.616    2.728       1.350  16.486     3.412
# 10     22.328         8.816    9.916       7.816  20.578     3.014
# 11     12.070        18.052   19.410       4.326  26.146     2.216
# 12     20.874        12.108   10.844       8.476  22.414     3.184
# 13     19.140        21.582   18.778       4.340  25.456     2.860
# 14     22.412        11.360   16.614      19.578  23.800     2.118
# 15     13.534        22.948   15.296       8.616  54.322     1.674
# 16     15.530        17.382   28.256      19.354  39.102     3.704
# 17     28.014        23.602   23.676      18.440  37.842     4.630
# 18     13.468        18.920   27.718      13.190  54.940     4.930
# 19     13.746        27.844   30.740       8.608  36.516     5.490
# 20     13.928        21.136   39.270       6.054  22.440     3.532
# 21      5.458        18.764   28.710       5.344  12.168     1.306
# 22      4.940        17.774   24.818       3.450  16.480     2.442
# 23      6.660        18.238   26.094       2.234  18.050     0.394
# 24      3.228        15.060   27.000       2.260  16.348     0.738
# 25      1.124         7.260   15.290       0.756   9.404     0.456
#
# genre     Top_Genre
# 0      release_year
# 1      release_year
# 2      release_year
# 3      release_year
# 4      release_year
# 5      release_year
# 6      release_year
# 7      release_year
# 8      release_year
# 9      release_year
# 10     release_year
# 11     release_year
# 12     release_year
# 13     release_year
# 14     release_year
# 15     release_year
# 16     release_year
# 17     release_year
# 18     release_year
# 19     release_year
# 20     release_year
# 21     release_year
# 22     release_year
# 23     release_year
# 24     release_year
# 25     release_year

# %%
#Identify the best performing genre by year

#df2.set_index('release_year')

#df2['Top_Genre'] = df[['Action','Adventure','Fighting','Misc','Platform','Puzzle','Racing','Role-Playing','Shooter','Simulation','Sports','Strategy']].idxmax(axis=1)

#df2['Top_Genre'] = df2.idxmax(axis=1)

#df2.head()

df2.dtypes
# Out:
# genre
# release_year      int64
# Action          float64
# Adventure       float64
# Fighting        float64
# Misc            float64
# Platform        float64
# Puzzle          float64
# Racing          float64
# Role-Playing    float64
# Shooter         float64
# Simulation      float64
# Sports          float64
# Strategy        float64
# Top_Genre        object
# dtype: object
