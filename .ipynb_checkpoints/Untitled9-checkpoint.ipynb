# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

df=pd.read_csv(r'C:/Python/datasets/Twitch_game_data_Original.csv',encoding='cp1252')


df.head()
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
#
#   Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0  1362044 hours        530270           2903     129172       127021
# 1   830105 hours        372654           2197     120849        64378
# 2   433397 hours        315083           1100      44074        60815
# 3   235903 hours        131357            517      36170        53749
# 4  1151578 hours         71639           3620     214054        21740
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# ...

# %%
#df.replace(to_replace=['Pok<U+00E9>mon Sword/Shield','Pok<U+00E9>mon Red/Blue','Pok<U+00E9>mon Brilliant Diamond/Shining Pearl'], 
           #value = ['Pokemon Sword/Shield','Pokemon Red/Blue','Pokemon Brilliant Diamond/Shining Pearl'])

df.replace(to_replace ='Pok<U+00E9>mon Sword/Shield',
               value ='Pokemon Sword/Shield')
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200              Pokemon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
data = pd.read_csv(r'C:/Python/datasets/Twitch_game_data_Original.csv',encoding='cp1252', nrows=75)
# Out:
#     Rank                                      Game  Month  Year  \
# 49    50        The Legend of Zelda: Majora's Mask      1  2016
# 50    51  Pok<U+00E9>mon Omega Ruby/Alpha Sapphire      1  2016
# 51    52                                   Duelyst      1  2016
# 52    53                               Garry's Mod      1  2016
# 53    54                            Super Mario 64      1  2016
# 54    55                                      osu!      1  2016
#
#     Hours_watched Hours_Streamed  Peak_viewers  Peak_channels  Streamers  \
# 49        1011289     4379 hours        141110             22        460
# 50         992216    20237 hours         11278             61       1428
# 51         870056     7939 hours         21769             31       1172
# 52         847981    35006 hours         26432            133       8326
# 53         828873     9001 hours        174067             31       1129
# 54         778404    71335 hours          9349            192      14698
#
# ...

# %%
df.replace(to_replace ='Pok<U+00E9>mon Omega Ruby/Alpha Sapphire', value= 'Pokemon Omega Ruby/Alpha Sapphire')


df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df[49:55]
# Out:
#     Rank                                      Game  Month  Year  \
# 49    50        The Legend of Zelda: Majora's Mask      1  2016
# 50    51  Pok<U+00E9>mon Omega Ruby/Alpha Sapphire      1  2016
# 51    52                                   Duelyst      1  2016
# 52    53                               Garry's Mod      1  2016
# 53    54                            Super Mario 64      1  2016
# 54    55                                      osu!      1  2016
#
#     Hours_watched Hours_Streamed  Peak_viewers  Peak_channels  Streamers  \
# 49        1011289     4379 hours        141110             22        460
# 50         992216    20237 hours         11278             61       1428
# 51         870056     7939 hours         21769             31       1172
# 52         847981    35006 hours         26432            133       8326
# 53         828873     9001 hours        174067             31       1129
# 54         778404    71335 hours          9349            192      14698
#
# ...

# %%
df.Game.unique()
# Out:
# array(['League of Legends', 'Counter-Strike: Global Offensive', 'Dota 2',
#        ..., 'The Elder Scrolls V: Skyrim Special Edition', 'DNF Duel',
#        'Pro Soccer Online'], dtype=object)

# %%
df.Hours_Streamed.unique()
# Out:
# array(['1362044 hours', '830105 hours', '433397 hours', ...,
#        '21753 hours', '223641 hours', '42291 hours'], dtype=object)

# %%
p = df['Hours_Streamed'].str
df['Hours_Streamed'] = np.where(p.endswith(' hours'),p.replace(' hours','',regex=True),p)
df
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14395   196                       Garry's Mod     12  2021         630902
# 14396   197  Call of Duty: Black Ops Cold War     12  2021         622497
# 14397   198                             Noita     12  2021         620983
# 14398   199                 Pro Soccer Online     12  2021         619859
# 14399   200       Pok<U+00E9>mon Sword/Shield     12  2021         615725
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df.Hours_Streamed.unique()
# Out:
# array(['1362044', '830105', '433397', ..., '21753', '223641', '42291'],
#       dtype=object)

# %%
df = df.dropna(how='any',axis=0) 
df["Hours_Streamed"].astype(np.int64)
# Out:
# 0        1362044
# 1         830105
# 2         433397
# 3         235903
# 4        1151578
#           ...
# 14395      21753
# 14396     223641
# 14397      13935
# 14398        606
# 14399      42291
# Name: Hours_Streamed, Length: 14399, dtype: int64

# %%
df.Hours_Streamed.unique()
# Out:
# array(['1362044', '830105', '433397', ..., '21753', '223641', '42291'],
#       dtype=object)

# %%
df.sort_values("Hours_watched")
# Out:
#        Rank                                  Game  Month  Year  Hours_watched  \
# 999     200                               iRacing      5  2016          89811
# 1199    200      The Mean Greens: Plastic Warfare      6  2016          92460
# 1198    199  Vampire: The Masquerade - Bloodlines      6  2016          92951
# 1799    200                    This Is the Police      9  2016          93135
# 998     199                     Age of Empires II      5  2016          93519
# ...     ...                                   ...    ...   ...            ...
# 12400     1                         Just Chatting      3  2021      270395369
# 14200     1                         Just Chatting     12  2021      271538951
# 12800     1                         Just Chatting      5  2021      285948196
# 12600     1                         Just Chatting      4  2021      289547911
# 10200     1                              VALORANT      4  2020      344551979
#
# ...

# %%
df.isnull()
# Out:
#         Rank   Game  Month   Year  Hours_watched  Hours_Streamed  \
# 0      False  False  False  False          False           False
# 1      False  False  False  False          False           False
# 2      False  False  False  False          False           False
# 3      False  False  False  False          False           False
# 4      False  False  False  False          False           False
# ...      ...    ...    ...    ...            ...             ...
# 14395  False  False  False  False          False           False
# 14396  False  False  False  False          False           False
# 14397  False  False  False  False          False           False
# 14398  False  False  False  False          False           False
# 14399  False  False  False  False          False           False
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0             False          False      False        False         False
# ...
