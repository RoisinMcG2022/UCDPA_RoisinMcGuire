# %%
import pandas as pd
import seaborn as sns

df=pd.read_csv(r'C:/Python/datasets/year_genre.csv')




#genre_wide = sns.load_dataset("df2").pivot("release_year", "sales", "genre")



df.head()
# Out:
#    release_year  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# 0          1991   2.704      0.896     0.156  0.032     3.054   1.296   0.456
# 1          1992   1.534      4.898     6.096  1.976     5.366   1.936   3.618
# 2          1993   0.724      0.028     3.500  0.120     7.470   1.268   0.144
# 3          1994   0.620      1.496     3.392  1.144    11.500   0.612   0.874
# 4          1995   1.430      0.286     5.938  2.560     6.676   1.080   2.436
#
#    Role-Playing  Shooter  Simulation  Sports  Strategy
# 0         1.302    0.798       0.858   0.964     0.376
# 1         2.744    0.114       0.856   1.180     0.148
# 2         2.236    1.232       0.076   1.272     0.324
# 3         2.848    3.320       1.090   3.360     1.426
# 4         5.706    1.660       1.670   3.194     2.610

# %%
df['Total_Sales'] = df['Action'] + df['Adventure'] +df['Fighting'] +df['Misc'] + df['Platform']+ df['Puzzle'] + df['Racing']+ df['Role-Playing'] + df['Shooter'] + df['Simulation'] + df['Sports'] + df['Strategy']

df.head()
# Out:
#    release_year  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# 0          1991   2.704      0.896     0.156  0.032     3.054   1.296   0.456
# 1          1992   1.534      4.898     6.096  1.976     5.366   1.936   3.618
# 2          1993   0.724      0.028     3.500  0.120     7.470   1.268   0.144
# 3          1994   0.620      1.496     3.392  1.144    11.500   0.612   0.874
# 4          1995   1.430      0.286     5.938  2.560     6.676   1.080   2.436
#
#    Role-Playing  Shooter  Simulation  Sports  Strategy  Total Sales  \
# 0         1.302    0.798       0.858   0.964     0.376       12.892
# 1         2.744    0.114       0.856   1.180     0.148       30.466
# 2         2.236    1.232       0.076   1.272     0.324       18.394
# 3         2.848    3.320       1.090   3.360     1.426       31.682
# 4         5.706    1.660       1.670   3.194     2.610       35.246
#
#    Total_Sales
# 0       12.892
# 1       30.466
# 2       18.394
# 3       31.682
# ...

# %%
sns.relplot(data=df, x="release_year", y="Action", hue="Shooter")
#sns.relplot(data=df, x="release_year", y="Total_Sales", hue="Shooter")
#sns.relplot(data=df, x="release_year", y="Total_Sales", hue="Fighting")

# %%
sns.relplot(data=df, x="release_year", y="Total_Sales", hue="Sports")
sns.relplot(data=df, x="release_year", y="Total_Sales", hue="Puzzle")
sns.relplot(data=df, x="release_year", y="Total_Sales", hue="Platform")

# %%
df.head()
# Out:
#    release_year  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# 0          1991   2.704      0.896     0.156  0.032     3.054   1.296   0.456
# 1          1992   1.534      4.898     6.096  1.976     5.366   1.936   3.618
# 2          1993   0.724      0.028     3.500  0.120     7.470   1.268   0.144
# 3          1994   0.620      1.496     3.392  1.144    11.500   0.612   0.874
# 4          1995   1.430      0.286     5.938  2.560     6.676   1.080   2.436
#
#    Role-Playing  Shooter  Simulation  Sports  Strategy  Total Sales  \
# 0         1.302    0.798       0.858   0.964     0.376       12.892
# 1         2.744    0.114       0.856   1.180     0.148       30.466
# 2         2.236    1.232       0.076   1.272     0.324       18.394
# 3         2.848    3.320       1.090   3.360     1.426       31.682
# 4         5.706    1.660       1.670   3.194     2.610       35.246
#
#    Total_Sales
# 0       12.892
# 1       30.466
# 2       18.394
# 3       31.682
# ...
